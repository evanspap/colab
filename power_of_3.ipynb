# %% [markdown]
# <a href="https://colab.research.google.com/github/evanspap/colab/blob/main/power_of_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
for n in range(1, 51):
    value = np.power(3, n, dtype=object)
    print(f"n = {n:2d} | 3^{n} = {value}")
# Out:
# n =  1 | 3^1 = 3
# n =  2 | 3^2 = 9
# n =  3 | 3^3 = 27
# n =  4 | 3^4 = 81
# n =  5 | 3^5 = 243
# n =  6 | 3^6 = 729
# n =  7 | 3^7 = 2187
# n =  8 | 3^8 = 6561
# n =  9 | 3^9 = 19683
# n = 10 | 3^10 = 59049
# n = 11 | 3^11 = 177147
# n = 12 | 3^12 = 531441
# n = 13 | 3^13 = 1594323
# n = 14 | 3^14 = 4782969
# n = 15 | 3^15 = 14348907
# n = 16 | 3^16 = 43046721
# n = 17 | 3^17 = 129140163
# n = 18 | 3^18 = 387420489
# n = 19 | 3^19 = 1162261467
# n = 20 | 3^20 = 3486784401
# n = 21 | 3^21 = 10460353203
# n = 22 | 3^22 = 31381059609
# n = 23 | 3^23 = 94143178827
# n = 24 | 3^24 = 282429536481
# n = 25 | 3^25 = 847288609443
# n = 26 | 3^26 = 2541865828329
# n = 27 | 3^27 = 7625597484987
# n = 28 | 3^28 = 22876792454961
# n = 29 | 3^29 = 68630377364883
# n = 30 | 3^30 = 205891132094649
# n = 31 | 3^31 = 617673396283947
# n = 32 | 3^32 = 1853020188851841
# n = 33 | 3^33 = 5559060566555523
# n = 34 | 3^34 = 16677181699666569
# n = 35 | 3^35 = 50031545098999707
# ...
